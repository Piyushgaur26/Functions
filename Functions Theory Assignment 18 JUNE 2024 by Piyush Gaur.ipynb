# %% [markdown]
# # ***Functions Theory Assignment 18 JUNE 2024 by Piyush Gaur***

# %% [markdown]
# ### 1. What is the difference between a function and a method in Python?
#
# **Function**:
# - A function is a block of code that performs a specific task.
# - It can be defined outside of classes.
# - Example:
#   ```python
#   def my_function():
#       print("This is a function.")
#
#   my_function()
#   ```
#
# **Method**:
# - A method is a function that is associated with an object.
# - It is defined within a class and typically operates on data contained within the class.
# - Example:
#   ```python
#   class MyClass:
#       def my_method(self):
#           print("This is a method.")
#
#   obj = MyClass()
#   obj.my_method()
#   ```
#
# ### 2. Explain the concept of function arguments and parameters in Python.
#
# - **Parameters** are variables listed inside the parentheses in the function definition.
# - **Arguments** are values passed to the function when it is called.
#
# **Example**:
# ```python
# def greet(name):  # 'name' is a parameter
#     print("Hello, " + name + "!")
#
# greet("Alice")  # "Alice" is an argument
# ```
#
# ### 3. What are the different ways to define and call a function in Python?
#
# - **Defining a function**:
#   ```python
#   def add(a, b):
#       return a + b
#   ```
#
# - **Calling a function**:
#   ```python
#   result = add(2, 3)
#   print(result)  # Output: 5
#   ```
#
# ### 4. What is the purpose of the `return` statement in a Python function?
#
# - The `return` statement is used to exit a function and go back to the place from where it was called.
# - It can also return a value to the caller.
#
# **Example**:
# ```python
# def square(x):
#     return x * x
#
# result = square(4)
# print(result)  # Output: 16
# ```
#
# ### 5. What are iterators in Python and how do they differ from iterables?
#
# - **Iterable**: An object that can be iterated over (e.g., lists, tuples, strings).
# - **Iterator**: An object that represents a stream of data; it returns data, one element at a time, when `next()` is called on it.
#
# **Example**:
# ```python
# # Iterable
# my_list = [1, 2, 3]
# for item in my_list:
#     print(item)
#
# # Iterator
# my_iter = iter(my_list)
# print(next(my_iter))  # Output: 1
# print(next(my_iter))  # Output: 2
# print(next(my_iter))  # Output: 3
# ```
#
# ### 6. Explain the concept of generators in Python and how they are defined.
#
# - **Generators** are a type of iterable, like lists or tuples.
# - Unlike lists, they do not store their contents in memory. Instead, they generate items on the fly.
# - Generators are defined using the `yield` keyword.
#
# **Example**:
# ```python
# def fibonacci(n):
#     a, b = 0, 1
#     for _ in range(n):
#         yield a
#         a, b = b, a + b
#
# for num in fibonacci(5):
#     print(num)  # Output: 0 1 1 2 3
# ```
#
# ### 7. What are the advantages of using generators over regular functions?
#
# - **Memory Efficiency**: Generators do not store all the values in memory, they generate each value only when needed.
# - **Lazy Evaluation**: They compute values on the fly and only when required.
# - **Composability**: Generators can be composed to form more complex data pipelines.
#
# ### 8. What is a lambda function in Python and when is it typically used?
#
# - **Lambda function**: A small anonymous function defined with the `lambda` keyword.
# - It can have any number of arguments, but only one expression.
#
# **Example**:
# ```python
# square = lambda x: x * x
# print(square(5))  # Output: 25
# ```
# - Typically used for short functions that are not reused, often as arguments to higher-order functions like `map`, `filter`, and `sorted`.
#
# ### 9. Explain the purpose and usage of the `map()` function in Python.
#
# - The `map()` function applies a given function to all items in an iterable and returns an iterator.
#
# **Example**:
# ```python
# numbers = [1, 2, 3, 4]
# squared = map(lambda x: x * x, numbers)
# print(list(squared))  # Output: [1, 4, 9, 16]
# ```
#
# ### 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
#
# - **`map()`**: Applies a function to all items in an iterable and returns an iterator.
#   ```python
#   numbers = [1, 2, 3, 4]
#   squared = map(lambda x: x * x, numbers)
#   print(list(squared))  # Output: [1, 4, 9, 16]
#   ```
#
# - **`filter()`**: Filters items out of an iterable, returning only those that meet a condition.
#   ```python
#   numbers = [1, 2, 3, 4]
#   even_numbers = filter(lambda x: x % 2 == 0, numbers)
#   print(list(even_numbers))  # Output: [2, 4]
#   ```
#
# - **`reduce()`**: Applies a rolling computation to sequential pairs of values in an iterable, reducing it to a single value (requires importing from `functools`).
#   ```python
#   from functools import reduce
#   numbers = [1, 2, 3, 4]
#   product = reduce(lambda x, y: x * y, numbers)
#   print(product)  # Output: 24
#   ```

# %% [markdown]
# #### 11 Use pen and paper to write the internal mechanism for sum operation using reduce function on the given list [47,11,42,13]

# %%
from functools import reduce

List=[47,11,42,13]
func=lambda a,b:a+b
reduce(func,List)
# Out:
# 113

# %% [markdown]
# ![image.png](attachment:image.png)
